# %% [markdown]
# <h1>Getting Started with your Lab Sandbox</h1>
# <p>You can find important course-specific tips and notes for your Lab Sandbox in this <br>
#     quick guide to use throughout your course. You’ll be able to reference this at any time <br>
#     or visit the <a href="https://learner.coursera.help/hc/articles/360062301971">Learner Help Center</a>
#     for more info. </p>
#
# <h2>What tools are already installed in my sandbox environment?</h2>
# <ul>
#   <li>Python 3</li>
#   <li>R </li>
#   <li>pysqldf</li>
#   <li>ast</li>
#   <li>pandas</li>
#   <li>numpy</li>
#   <li>pandasql</li>
#   <li>scikit-learn</li>
#   <li>tweepy</li>
#   <li>nltk</li>
#   <li>wordcloud</li>
#   <li>textblob</li>
#   <li>erdantic (ERD Diagrams)</li>
#   <li>Many more! You can find these by running "!pip list" in a Jupyter Notebook cell.</li>
# </ul>
#
#
# <h2>How can I use this Sandbox with the course materials?</h2>
#
# <b>Important Note about this Course:</b><br> This course utilizes additional tools (Mode Analytics and Databricks) for ungraded exercises, which can be accessed <br>
# in your browser without local software downloads.
# If you have any issues accessing Notebooks from the prior courses<br>
# in the specialization, more information can be found in the lecture video below, which can help you complete ungraded work:<br>
# <a href="https://www.coursera.org/lecture/spark-sql/the-databricks-environment-oVpus">Databricks Setup and Notebooks</a>
#
# <b> Please note that this sandbox does not replace Databricks and Mode Analytics tools.</b><br>
# The course team has set them up with care for specifics of this course, and you should use them to complete <br> relevant course activities where possible. You may also choose to use these environments only to complete <br>
# your project. This Sandbox is a completely optional environment that can be utilized to complete<br> basic data analysis needed to complete the required Peer Review assessments in this course.<br>
#
#
# <h2>How can I run Python in terminal in the Lab Sandbox?</h2>
# <ol>Type  <b>python[version]</b> followed by your filename. For example, python3 filename.py </ol>
#
# <h2> How can I execute SQLite queries in the Lab Sandbox?</h2>
# <ol>
#     <li>After launching the lab, Click on <b>New(dropdown)</b> -><b>Terminal</b> to open a new terminal. </li>
#     <li>Once the terminal is launched  type <strong>sqlite3</strong> to launch the sqlite.</li>
#     Now, you will be able to execute the queries.
#     <br><br>
#     <b>To come out of the sqlite you can press Ctrl+D keys. </b>
# </ol>
#
# <h2>How can I create an ERD diagram in the Lab Sandbox?</h2>
#
# - There are many tools you can accces in browser and locally to create an ERD diagram.<br>
# - If you are unable to utilize tools recommended in the course due to network requirements, a pip package, <a href="https://erdantic.drivendata.org/stable/examples/pydantic/">Erdantic</a> is available. <br>
# which can help you generate ERD diagrams.
# - More information on how to use this tool can be found <a href="https://erdantic.drivendata.org/stable/examples/pydantic/">here. </a>
# - A quick example of Erdantic output and capabilites can be found below:

# %%
# !pip install -U erdantic

import erdantic as erd
from erdantic.examples.pydantic import Party


diagram = erd.create(Party)
diagram
# Out:
# Collecting erdantic
#   Using cached erdantic-0.5.0-py3-none-any.whl (28 kB)
# Requirement already satisfied: typer in /Users/eduardofelix/opt/anaconda3/lib/python3.9/site-packages (from erdantic) (0.6.1)
# Collecting pygraphviz
#   Using cached pygraphviz-1.9.zip (119 kB)
# Requirement already satisfied: typing-extensions in /Users/eduardofelix/opt/anaconda3/lib/python3.9/site-packages (from erdantic) (3.10.0.2)
# Collecting pydantic
#   Using cached pydantic-1.9.1-cp39-cp39-macosx_10_9_x86_64.whl (3.0 MB)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/eduardofelix/opt/anaconda3/lib/python3.9/site-packages (from typer->erdantic) (8.0.3)
# Building wheels for collected packages: pygraphviz
#   Building wheel for pygraphviz (setup.py) ... error
#   ERROR: Command errored out with exit status 1:
#    command: /Users/eduardofelix/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/setup.py'"'"'; __file__='"'"'/private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-wheel-gbr3a_lf
#        cwd: /private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/
#   Complete output (55 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.macosx-10.9-x86_64-3.9
#   creating build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   copying pygraphviz/scraper.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   copying pygraphviz/graphviz.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   copying pygraphviz/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   copying pygraphviz/agraph.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   copying pygraphviz/testing.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   creating build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_unicode.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_scraper.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_readwrite.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_string.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_html.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_node_attributes.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_drawing.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_repr_mimebundle.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_subgraph.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_close.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_edge_attributes.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_clear.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_layout.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_attribute_defaults.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   copying pygraphviz/tests/test_graph.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#   running egg_info
#   writing pygraphviz.egg-info/PKG-INFO
#   writing dependency_links to pygraphviz.egg-info/dependency_links.txt
#   writing top-level names to pygraphviz.egg-info/top_level.txt
#   reading manifest file 'pygraphviz.egg-info/SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching '*.png' under directory 'doc'
#   warning: no files found matching '*.txt' under directory 'doc'
#   warning: no files found matching '*.css' under directory 'doc'
#   warning: no previously-included files matching '*~' found anywhere in distribution
#   warning: no previously-included files matching '*.pyc' found anywhere in distribution
#   warning: no previously-included files matching '.svn' found anywhere in distribution
#   no previously-included directories found matching 'doc/build'
#   adding license file 'LICENSE'
#   writing manifest file 'pygraphviz.egg-info/SOURCES.txt'
#   copying pygraphviz/graphviz.i -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   copying pygraphviz/graphviz_wrap.c -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#   running build_ext
#   building 'pygraphviz._graphviz' extension
#   creating build/temp.macosx-10.9-x86_64-3.9
#   creating build/temp.macosx-10.9-x86_64-3.9/pygraphviz
#   clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/eduardofelix/opt/anaconda3/include -arch x86_64 -I/Users/eduardofelix/opt/anaconda3/include -fPIC -O2 -isystem /Users/eduardofelix/opt/anaconda3/include -arch x86_64 -I/Users/eduardofelix/opt/anaconda3/include/python3.9 -c pygraphviz/graphviz_wrap.c -o build/temp.macosx-10.9-x86_64-3.9/pygraphviz/graphviz_wrap.o
#   pygraphviz/graphviz_wrap.c:2711:10: fatal error: 'graphviz/cgraph.h' file not found
#   #include "graphviz/cgraph.h"
#            ^~~~~~~~~~~~~~~~~~~
#   1 error generated.
#   error: command '/usr/bin/clang' failed with exit code 1
#   ----------------------------------------
#   ERROR: Failed building wheel for pygraphviz
#   Running setup.py clean for pygraphviz
# Failed to build pygraphviz
# Installing collected packages: pygraphviz, pydantic, erdantic
#     Running setup.py install for pygraphviz ... error
#     ERROR: Command errored out with exit status 1:
#      command: /Users/eduardofelix/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/setup.py'"'"'; __file__='"'"'/private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-record-0k79ntpz/install-record.txt --single-version-externally-managed --compile --install-headers /Users/eduardofelix/opt/anaconda3/include/python3.9/pygraphviz
#          cwd: /private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/
#     Complete output (55 lines):
#     running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.macosx-10.9-x86_64-3.9
#     creating build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     copying pygraphviz/scraper.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     copying pygraphviz/graphviz.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     copying pygraphviz/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     copying pygraphviz/agraph.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     copying pygraphviz/testing.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     creating build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_unicode.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_scraper.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_readwrite.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_string.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/__init__.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_html.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_node_attributes.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_drawing.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_repr_mimebundle.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_subgraph.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_close.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_edge_attributes.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_clear.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_layout.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_attribute_defaults.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     copying pygraphviz/tests/test_graph.py -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz/tests
#     running egg_info
#     writing pygraphviz.egg-info/PKG-INFO
#     writing dependency_links to pygraphviz.egg-info/dependency_links.txt
#     writing top-level names to pygraphviz.egg-info/top_level.txt
#     reading manifest file 'pygraphviz.egg-info/SOURCES.txt'
#     reading manifest template 'MANIFEST.in'
#     warning: no files found matching '*.png' under directory 'doc'
#     warning: no files found matching '*.txt' under directory 'doc'
#     warning: no files found matching '*.css' under directory 'doc'
#     warning: no previously-included files matching '*~' found anywhere in distribution
#     warning: no previously-included files matching '*.pyc' found anywhere in distribution
#     warning: no previously-included files matching '.svn' found anywhere in distribution
#     no previously-included directories found matching 'doc/build'
#     adding license file 'LICENSE'
#     writing manifest file 'pygraphviz.egg-info/SOURCES.txt'
#     copying pygraphviz/graphviz.i -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     copying pygraphviz/graphviz_wrap.c -> build/lib.macosx-10.9-x86_64-3.9/pygraphviz
#     running build_ext
#     building 'pygraphviz._graphviz' extension
#     creating build/temp.macosx-10.9-x86_64-3.9
#     creating build/temp.macosx-10.9-x86_64-3.9/pygraphviz
#     clang -Wno-unused-result -Wsign-compare -Wunreachable-code -DNDEBUG -fwrapv -O2 -Wall -fPIC -O2 -isystem /Users/eduardofelix/opt/anaconda3/include -arch x86_64 -I/Users/eduardofelix/opt/anaconda3/include -fPIC -O2 -isystem /Users/eduardofelix/opt/anaconda3/include -arch x86_64 -I/Users/eduardofelix/opt/anaconda3/include/python3.9 -c pygraphviz/graphviz_wrap.c -o build/temp.macosx-10.9-x86_64-3.9/pygraphviz/graphviz_wrap.o
#     pygraphviz/graphviz_wrap.c:2711:10: fatal error: 'graphviz/cgraph.h' file not found
#     #include "graphviz/cgraph.h"
#              ^~~~~~~~~~~~~~~~~~~
#     1 error generated.
#     error: command '/usr/bin/clang' failed with exit code 1
#     ----------------------------------------
# ERROR: Command errored out with exit status 1: /Users/eduardofelix/opt/anaconda3/bin/python -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/setup.py'"'"'; __file__='"'"'/private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-install-x8ustcwy/pygraphviz_051db52e00804d35a6cb1dc9be028971/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /private/var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/pip-record-0k79ntpz/install-record.txt --single-version-externally-managed --compile --install-headers /Users/eduardofelix/opt/anaconda3/include/python3.9/pygraphviz Check the logs for full command output.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/ipykernel_2828/3345488309.py in <module>
#       1 get_ipython().system('pip install -U erdantic')
#       2
# ----> 3 import erdantic as erd
#       4 from erdantic.examples.pydantic import Party
#       5
#
# ModuleNotFoundError: No module named 'erdantic'

# %%
import erdantic.examples.pydantic
??erdantic.examples.pydantic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/1f/wvzjrpds3p112qz68tsk809m0000gn/T/ipykernel_2828/995526879.py in <module>
# ----> 1 import erdantic.examples.pydantic
#       2 get_ipython().run_line_magic('pinfo2', 'erdantic.examples.pydantic')
#
# ModuleNotFoundError: No module named 'erdantic'

# %% [markdown]
# <h2>Additional Course Specific Notes:</h2>
#
# <ul>
#     <li>You can use the Python kernel in the lab environment by choosing the <br>
#         right kernel from the menu, or in the "New" dropdown selecting your notebook type. </li>
#     <li><b>IMPORTANT: To optimize your notebook performance, please shut down each of your <br>
#         open/running Jupyter Notebooks after you complete them within your Lab</b>. <br>
#         This will provide full and dedicated system resources to the current lab assignment<br>
#         you are working on in your Lab Sandbox. If you experience any unexpected slow <br>
#         processing in your notebook, try to restart your Lab kernel and only open that single <br>
#         notebook to complete your work. You can learn more about restarting your Lab Sandbox <br>
#         and troubleshooting your lab in our Learner Help Center article <a href="https://learner.coursera.help/hc/articles/360044758731-Solving-Common-Issues-with-Coursera-Labs">here</a>.</li><br>
#     <li>If anything is unclear regarding the course content, please go through the Discussion board and see if your question has been answered. <br>If you have any issues with the Jupyter enviornment itself, please contact Coursera through the <a href="https://learner.coursera.help">Learner Help Center.</a></li><br>
# </ul>
